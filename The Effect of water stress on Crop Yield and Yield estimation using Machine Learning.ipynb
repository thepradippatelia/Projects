# %% [markdown]
# #### Importing the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Reading the dataset

# %%
df = pd.read_excel(r"C:\Users\thepr\Desktop\Final_Project_Data\final.xlsx")

# %%
df
# Out:
#         Year                    District      NDVI  T-min(Kelvin)  \
# 0    2000-01                    Amritsar  0.421800     291.962301
# 1    2000-01                    Bathinda  0.383781     292.597252
# 2    2000-01                    Faridkot  0.408001     292.511493
# 3    2000-01             Fatehgarh Sahib  0.447948     292.335116
# 4    2000-01                    Firozpur  0.425524     292.287922
# ..       ...                         ...       ...            ...
# 392  2019-20                    Rupnagar  0.351875     290.882356
# 393  2019-20                     Sangrur  0.378430     292.412082
# 394  2019-20  Sahibzada Ajit Singh Nagar  0.339649     291.676825
# 395  2019-20   Shahid Bhagat Singh Nagar  0.355314     291.823587
# 396  2019-20                  Tarn Taran  0.357771     291.847724
#
#      T-max(Kelvin)  Soil_Moisture  Total_Precipitation(mm)  Total_ET(mm)  \
# 0       307.384153      20.145042               608.380271   2683.837844
# ...

# %% [markdown]
# #### Columns present in the dataset

# %%
df.columns
# Out:
# Index(['Year', 'District', 'NDVI', 'T-min(Kelvin)', 'T-max(Kelvin)',
#        'Soil_Moisture', 'Total_Precipitation(mm)', 'Total_ET(mm)',
#        'Total_PET(mm)', 'Yield (Tonnes/Hectare)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     397 non-null    object
#  1   District                 397 non-null    object
#  2   NDVI                     397 non-null    float64
#  3   T-min(Kelvin)            397 non-null    float64
#  4   T-max(Kelvin)            397 non-null    float64
#  5   Soil_Moisture            397 non-null    float64
#  6   Total_Precipitation(mm)  397 non-null    float64
#  7   Total_ET(mm)             397 non-null    float64
#  8   Total_PET(mm)            397 non-null    float64
#  9   Yield (Tonnes/Hectare)   397 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 31.1+ KB

# %% [markdown]
# # EDA

# %%
plt.style.use('seaborn-whitegrid')
a,b = np.polyfit(df['Soil_Moisture'],df['Total_Precipitation(mm)'],1)
plt.scatter(df['Soil_Moisture'],df['Total_Precipitation(mm)'],cmap='viridis')
plt.plot(df['Soil_Moisture'],a*df['Soil_Moisture']+b,color='red')
plt.xlabel('Soil Moisture(mm)')
plt.ylabel('Total Precipitation(mm)')
plt.title('Soil Moisture vs. Total Precipitation')
plt.show()

# %%
plt.style.use('seaborn-whitegrid')
a,b = np.polyfit(df['Soil_Moisture'],df['Yield (Tonnes/Hectare)'],1)
plt.scatter(df['Soil_Moisture'],df['Yield (Tonnes/Hectare)'],cmap='viridis')
plt.plot(df['Soil_Moisture'],a*df['Soil_Moisture']+b,color='red')
plt.xlabel('Soil Moisture')
plt.ylabel('Yield (Tonnes/Hectare)')
plt.title('Soil Moisture vs. Yield')
plt.show()

# %%
plt.style.use('seaborn-whitegrid')
a,b = np.polyfit(df['Total_Precipitation(mm)'],df['Yield (Tonnes/Hectare)'],1)
plt.scatter(df['Total_Precipitation(mm)'],df['Yield (Tonnes/Hectare)'],cmap='viridis')
plt.plot(df['Total_Precipitation(mm)'],a*df['Total_Precipitation(mm)']+b,color='red')
plt.xlabel('Total_Precipitation(mm)')
plt.ylabel('Yield (Tonnes/Hectare)')
plt.title('Total Precipitation vs. Yield')
plt.show()

# %%
plt.style.use('seaborn-whitegrid')
a,b = np.polyfit(df['Total_ET(mm)'],df['Yield (Tonnes/Hectare)'],1)
plt.scatter(df['Total_ET(mm)'],df['Yield (Tonnes/Hectare)'],cmap='viridis')
plt.plot(df['Total_ET(mm)'],a*df['Total_ET(mm)']+b,color='red')
plt.xlabel('Total_ET(mm)')
plt.ylabel('Yield (Tonnes/Hectare)')
plt.title('Total ET vs Yield')
plt.show()

# %%
X = df['Total_ET(mm)']/df['Total_PET(mm)']
Y = df['Yield (Tonnes/Hectare)']

# %%
plt.style.use('seaborn-whitegrid')
a,b = np.polyfit(X,Y,1)
plt.scatter(X,Y,cmap='viridis')
plt.plot(X,a*X+b,color='red')
plt.xlabel('ET/PET')
plt.ylabel('Yield (Tonnes/Hectare)')
plt.title('Ratio of ET to PET vs Yield')
plt.show()

# %%
plt.style.use('seaborn-whitegrid')
a,b = np.polyfit(df['Total_ET(mm)'],df['NDVI'],1)
plt.scatter(df['Total_ET(mm)'],df['NDVI'],cmap='viridis')
plt.plot(df['Total_ET(mm)'],a*df['Total_ET(mm)']+b,color='red')
plt.xlabel('Total_ET(mm)')
plt.ylabel('NDVI')
plt.title('Total ET vs NDVI')
plt.show()

# %%
X = df['Total_ET(mm)']/df['Total_PET(mm)']
Y = df['NDVI']

# %%
plt.grid(True)
a,b = np.polyfit(X,Y,1)
plt.scatter(X,Y,cmap='viridis')
plt.plot(X,a*X+b,color='red')
plt.xlabel('ET/PET')
plt.ylabel('NDVI')
plt.title('Ratio of ET to PET vs NDVI')
plt.show()

# %%
plt.grid(True)
a,b = np.polyfit(df['NDVI'],df['Yield (Tonnes/Hectare)'],1)
plt.scatter(df['NDVI'],df['Yield (Tonnes/Hectare)'],cmap='viridis')
plt.plot(df['NDVI'],a*df['NDVI']+b,color='red')
plt.xlabel('NDVI')
plt.ylabel('Yield')
plt.title('NDVI vs. Yield')
plt.show()

# %% [markdown]
# #### Correlation among the variables

# %%
sns.heatmap(df.corr(),annot=True,center=1)
plt.show()

# %% [markdown]
# #### Due to the multicolinearity among some of the variables, we need to drop these variable causing multicolinearity as well as unnecessary column

# %%
df.drop(columns=['Total_Precipitation(mm)','T-min(Kelvin)','Year'],inplace=True)

# %% [markdown]
# #### Data distribution across all the variables

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# #### Descriptive statistics of the dataset

# %%
df.describe()
# Out:
#              NDVI  T-max(Kelvin)  Soil_Moisture  Total_ET(mm)  Total_PET(mm)  \
# count  397.000000     397.000000     397.000000    397.000000     397.000000
# mean     0.392162     307.005616      14.223619   1854.645912    7779.386901
# std      0.033107       2.444509       3.438916    425.481320     587.468408
# min      0.308472     300.244449       8.114371    956.442293    6253.014081
# 25%      0.367758     305.515771      11.721977   1562.263818    7407.828096
# 50%      0.392775     307.186822      13.697927   1823.838274    7827.730471
# 75%      0.414961     308.671396      16.279740   2166.879773    8167.742668
# max      0.469956     312.094093      27.538283   3160.007887    9827.009398
#
#        Yield (Tonnes/Hectare)
# count              397.000000
# mean                 4.576804
# std                  0.513961
# min                  2.738095
# 25%                  4.233533
# 50%                  4.582090
# 75%                  4.927273
# ...

# %% [markdown]
# #### Splitting the dataframe into two dataframes, one includes input columns and  the second one includes target variable

# %%
X = df.drop('Yield (Tonnes/Hectare)',axis=1)
y = df['Yield (Tonnes/Hectare)']

# %% [markdown]
# #### Splitting the datasets into train and test datasets

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1,random_state=32)

# %% [markdown]
# #### Now, in order to train the model, we have to encode our categorical variable.

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
X_train['District'] = encoder.fit_transform(X_train['District'])
X_test['District'] = encoder.transform(X_test['District'])

# %% [markdown]
# #### Features in our input dataset have different range of values, so we need to standarize them to bring them into same scale

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## `Linear Regression`

# %% [markdown]
# #### We need to first import the model

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression()

# %% [markdown]
# #### Fitting the model with train dataset

# %%
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Checking the accuracy on train data itself as model is trained

# %%
LR.score(X_train,y_train)
# Out:
# 0.3782622849184054

# %% [markdown]
# #### Prediction on test dataset

# %%
y_pred = LR.predict(X_test)

# %% [markdown]
# #### Model performance on test dataset

# %%
from sklearn.metrics import r2_score, mean_squared_error
print("r2_score:",r2_score(y_test,y_pred))
print("mean_squared_error:",mean_squared_error(y_test,y_pred))
# Out:
# r2_score: 0.5120384115059112
# mean_squared_error: 0.13356636198504632

# %% [markdown]
# #### It seems like our dataset is not linearly distributed so we need to use complex ML algorithms in order to get better accuracy

# %% [markdown]
# # `Polynomial Linear Regression`

# %% [markdown]
# #### Need to first import the model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# #### Creating polynomial features

# %%
poly = PolynomialFeatures(degree=3)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %% [markdown]
# #### Fitting a linear regression model to the polynomial features

# %%
reg = LinearRegression()
reg.fit(X_train_poly, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Prediction on test dataset

# %%
y_pred = reg.predict(X_test_poly)

# %% [markdown]
# #### Model Evaluation

# %%
from sklearn.metrics import r2_score, mean_squared_error
print("r2_score:",r2_score(y_test,y_pred))
print("mean_squared_error:",mean_squared_error(y_test,y_pred))
# Out:
# r2_score: 0.613694324986684
# mean_squared_error: 0.10574078952595936

# %% [markdown]
# # `Decision Tree`

# %% [markdown]
# #### Need to first import the model

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DT = DecisionTreeRegressor()

# %% [markdown]
# #### we need tune the hyperparameters, so we must use GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'max_depth': [3, 5, 7],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 2, 4],
              'max_features': [None, 'sqrt', 'log2']}

# %%
grid = GridSearchCV(DT,param_grid=param_grid,cv=5)

# %% [markdown]
# #### Fitting the model with train dataset

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [3, 5, 7],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]})

# %% [markdown]
# #### Model's  performance on train dataset

# %%
grid.score(X_train,y_train)
# Out:
# 0.7224548598194782

# %% [markdown]
# #### Prediction on test dataset

# %%
y_pred=grid.predict(X_test)

# %% [markdown]
# #### Model Evaluation

# %%
from sklearn.metrics import r2_score, mean_squared_error
print("r2_score:",r2_score(y_test,y_pred))
print("mean_squared_error:",mean_squared_error(y_test,y_pred))
# Out:
# r2_score: 0.03118401590741182
# mean_squared_error: 0.2651873210503271

# %% [markdown]
# # `Random Forest`

# %% [markdown]
# #### Need to first import the model

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF = RandomForestRegressor(n_estimators=250,max_depth=15,min_samples_split=2,min_samples_leaf=2)

# %% [markdown]
# #### Fitting the model with train dataset

# %%
RF.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=15, min_samples_leaf=2, n_estimators=250)

# %% [markdown]
# #### Predictions on test dataset

# %%
y_pred = RF.predict(X_test)

# %% [markdown]
# #### Model Evaluation

# %%
from sklearn.metrics import r2_score, mean_squared_error
print("r2_score:",r2_score(y_test,y_pred))
print("mean_squared_error:",mean_squared_error(y_test,y_pred))
# Out:
# r2_score: 0.5998594175603851
# mean_squared_error: 0.1095277233685051

# %% [markdown]
# # `LGBM`

# %% [markdown]
# #### Importing the model first

# %%
from lightgbm import LGBMRegressor

# %%
LGBM = LGBMRegressor()

# %% [markdown]
# #### Tuning the hyperparameters

# %%
param_grid = {'learning_rate': [0.01, 0.1],
    'num_leaves': [10, 20, 30],
    'max_depth': [-1, 5, 10]}

# %%
grid = GridSearchCV(LGBM,param_grid=param_grid,cv=5)

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LGBMRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1], 'max_depth': [-1, 5, 10],
#                          'num_leaves': [10, 20, 30]})

# %% [markdown]
# #### Model's performance on test dataset

# %%
grid.score(X_train,y_train)
# Out:
# 0.8692535761022059

# %% [markdown]
# #### Making the prediction on test dataset

# %%
y_pred = grid.predict(X_test)

# %% [markdown]
# #### Model evaluation

# %%
from sklearn.metrics import r2_score, mean_squared_error
print("r2_score:",r2_score(y_test,y_pred))
print("mean_squared_error:",mean_squared_error(y_test,y_pred))
# Out:
# r2_score: 0.6632052767217713
# mean_squared_error: 0.09218849799809262

# %% [markdown]
# # `XGBoost`

# %% [markdown]
# #### Importing the model first

# %%
from xgboost import XGBRegressor

# %%
XGB = XGBRegressor()

# %% [markdown]
# #### Tuning the hyperparameters

# %%
param_grid = {
    'learning_rate': [0.01,0.1, 0.01, 0.001],
    'max_depth': [2,3, 5, 7],
    'n_estimators': [50, 100, 200]
}

# %%
grid = GridSearchCV(XGB,param_grid=param_grid,cv=5)

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...e,
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
# ...

# %% [markdown]
# #### Model's performance on train dataset

# %%
grid.score(X_train,y_train)
# Out:
# 0.8527038590221048

# %% [markdown]
# #### Prediction on test dataset

# %%
y_pred = grid.predict(X_test)

# %% [markdown]
# #### Model evalution

# %%
from sklearn.metrics import r2_score, mean_squared_error
print("r2_score:",r2_score(y_test,y_pred))
print("mean_squared_error:",mean_squared_error(y_test,y_pred))
# Out:
# r2_score: 0.6726876200258397
# mean_squared_error: 0.08959296152948179
